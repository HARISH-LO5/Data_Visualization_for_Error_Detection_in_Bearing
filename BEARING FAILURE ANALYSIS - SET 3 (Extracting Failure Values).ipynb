# %%
import matplotlib.pyplot as plt
import scipy.io
import pandas as pd
import numpy as np
import os

def skewness(x):
    n = len(x)
    a = np.sum((x - np.mean(x))**3)/n
    b = np.std(x,ddof =1)**3
    return a/b

def kurtosis(x):
    n = len(x)
    a = np.sum((x - np.mean(x))**4)/n
    b = np.std(x,ddof =1)**4
    return a/b - 3
    
#TEST SET 3 BEARING NO 1

set3bear1 = pd.DataFrame()
test_set = 3
bearing_no = 1
path = r'D:\Bearing project Dataset\3rd_test\4th_test\txt'
for filename in os.listdir(path):
    dataset = pd.read_csv(os.path.join(path,filename), sep = '\t', header = None)
    datarr = np.array(dataset.iloc[:,bearing_no-1])
    feature_matrix = np.zeros((1,9))
    temp = datarr
    feature_matrix[0,0] = np.max(temp)
    feature_matrix[0,1] = np.min(temp)
    feature_matrix[0,2] = np.mean(temp)
    feature_matrix[0,3] = np.std(temp, ddof =1)
    feature_matrix[0,4] = np.sqrt(np.mean(temp**2))
    feature_matrix[0,5] = skewness(temp)
    feature_matrix[0,6] = kurtosis(temp)
    feature_matrix[0,7] = feature_matrix[0,0]/feature_matrix[0,4]
    feature_matrix[0,8] = feature_matrix[0,4]/feature_matrix[0,2]
    df1= pd.DataFrame(feature_matrix)
    df1.index = [filename[:-3]]
    set3bear1 = pd.concat([set3bear1,df1])

set3bear1.columns = ['Max', 'Min', 'Mean', 'Standard Deviation', 'RMS', 'Skewness', 'Kurtosis', 'Crest Factor', 'Form Factor']
set3bear1.index = pd.to_datetime(set3bear1.index, format ='%Y.%m.%d.%H.%M')
set3bear1.to_csv('Bearing_values_bearingno{}_testset{}.csv'.format(bearing_no,test_set))
set3bear1
# Out:
#                        Max    Min      Mean  Standard Deviation       RMS  \
# 2004-03-04 09:27:00  0.547 -0.569 -0.004715            0.079631  0.079768
# 2004-03-04 09:32:00  0.491 -0.461 -0.005102            0.078514  0.078678
# 2004-03-04 09:42:00  0.515 -0.454 -0.002242            0.079785  0.079815
# 2004-03-04 09:52:00  0.520 -0.552 -0.002552            0.081044  0.081082
# 2004-03-04 10:02:00  0.369 -0.381 -0.002534            0.079126  0.079165
# ...                    ...    ...       ...                 ...       ...
# 2004-04-18 02:02:00  0.742 -0.667 -0.002483            0.154769  0.154785
# 2004-04-18 02:12:00  0.613 -0.576 -0.001885            0.137860  0.137870
# 2004-04-18 02:22:00  0.754 -0.688 -0.002402            0.147165  0.147181
# 2004-04-18 02:32:00  0.933 -0.632 -0.003033            0.154456  0.154482
# 2004-04-18 02:42:00  0.005 -0.002  0.001533            0.001143  0.001912
#
#                      Skewness  Kurtosis  Crest Factor  Form Factor
# 2004-03-04 09:27:00  0.030875  1.292301      6.857363   -16.919417
# 2004-03-04 09:32:00 -0.013806  1.156631      6.240622   -15.422493
# 2004-03-04 09:42:00  0.033417  0.889743      6.452419   -35.600825
# 2004-03-04 09:52:00 -0.027038  1.181453      6.413225   -31.769056
# 2004-03-04 10:02:00 -0.017774  0.585448      4.661149   -31.240121
# ...                       ...       ...           ...          ...
# 2004-04-18 02:02:00  0.161841  0.284098      4.793745   -62.334039
# 2004-04-18 02:12:00  0.109001  0.035104      4.446217   -73.121270
# 2004-04-18 02:22:00  0.291569  0.552675      5.122955   -61.285383
# 2004-04-18 02:32:00  0.440079  1.093348      6.039545   -50.941742
# 2004-04-18 02:42:00  0.436012  1.299470      2.615004     1.247289
#
# [6324 rows x 9 columns]

# %%
#TEST SET 3 BEARING NO 2

set3bear2 = pd.DataFrame()
test_set = 3
bearing_no = 2
path = r'D:\Bearing project Dataset\3rd_test\4th_test\txt'
for filename in os.listdir(path):
    dataset = pd.read_csv(os.path.join(path,filename), sep = '\t', header = None)
    datarr = np.array(dataset.iloc[:,bearing_no-1])
    feature_matrix = np.zeros((1,9))
    temp = datarr
    feature_matrix[0,0] = np.max(temp)
    feature_matrix[0,1] = np.min(temp)
    feature_matrix[0,2] = np.mean(temp)
    feature_matrix[0,3] = np.std(temp, ddof =1)
    feature_matrix[0,4] = np.sqrt(np.mean(temp**2))
    feature_matrix[0,5] = skewness(temp)
    feature_matrix[0,6] = kurtosis(temp)
    feature_matrix[0,7] = feature_matrix[0,0]/feature_matrix[0,4]
    feature_matrix[0,8] = feature_matrix[0,4]/feature_matrix[0,2]
    df1= pd.DataFrame(feature_matrix)
    df1.index = [filename[:-3]]
    set3bear2 = pd.concat([set3bear2,df1])

set3bear2.columns = ['Max', 'Min', 'Mean', 'Standard Deviation', 'RMS', 'Skewness', 'Kurtosis', 'Crest Factor', 'Form Factor']
set3bear2.index = pd.to_datetime(set3bear2.index, format ='%Y.%m.%d.%H.%M')
set3bear2.to_csv('Bearing_values_bearingno{}_testset{}.csv'.format(bearing_no,test_set))
set3bear2
# Out:
#                        Max    Min      Mean  Standard Deviation       RMS  \
# 2004-03-04 09:27:00  0.527 -0.437 -0.003905            0.096643  0.096720
# 2004-03-04 09:32:00  0.537 -0.479 -0.005115            0.091868  0.092008
# 2004-03-04 09:42:00  0.496 -0.596 -0.002249            0.093405  0.093430
# 2004-03-04 09:52:00  0.476 -0.513 -0.001115            0.092799  0.092803
# 2004-03-04 10:02:00  0.518 -0.562 -0.000780            0.092828  0.092829
# ...                    ...    ...       ...                 ...       ...
# 2004-04-18 02:02:00  0.872 -0.886 -0.001246            0.234438  0.234436
# 2004-04-18 02:12:00  0.891 -0.818 -0.002077            0.207223  0.207229
# 2004-04-18 02:22:00  0.864 -0.847 -0.002420            0.250652  0.250657
# 2004-04-18 02:32:00  0.962 -1.292 -0.002095            0.257198  0.257200
# 2004-04-18 02:42:00  0.007  0.000  0.002441            0.001351  0.002789
#
#                      Skewness  Kurtosis  Crest Factor  Form Factor
# 2004-03-04 09:27:00  0.152035  0.776082      5.448737   -24.769832
# 2004-03-04 09:32:00  0.146235  0.701574      5.836461   -17.987875
# 2004-03-04 09:42:00  0.171792  0.936283      5.308774   -41.542582
# 2004-03-04 09:52:00  0.166062  0.379024      5.129135   -83.228634
# 2004-03-04 10:02:00  0.145970  0.503687      5.580131  -119.067164
# ...                       ...       ...           ...          ...
# 2004-04-18 02:02:00  0.076449 -0.102991      3.719571  -188.084871
# 2004-04-18 02:12:00 -0.016977 -0.040071      4.299600   -99.779970
# 2004-04-18 02:22:00 -0.029070 -0.230784      3.446939  -103.563982
# 2004-04-18 02:32:00 -0.156068  0.658018      3.740276  -122.750315
# 2004-04-18 02:42:00  0.906357  0.330281      2.509546     1.142929
#
# [6324 rows x 9 columns]

# %%
#TEST SET 3 BEARING NO 3

set3bear3 = pd.DataFrame()
test_set = 3
bearing_no = 3
path = r'D:\Bearing project Dataset\3rd_test\4th_test\txt'
for filename in os.listdir(path):
    dataset = pd.read_csv(os.path.join(path,filename), sep = '\t', header = None)
    datarr = np.array(dataset.iloc[:,bearing_no-1])
    feature_matrix = np.zeros((1,9))
    temp = datarr
    feature_matrix[0,0] = np.max(temp)
    feature_matrix[0,1] = np.min(temp)
    feature_matrix[0,2] = np.mean(temp)
    feature_matrix[0,3] = np.std(temp, ddof =1)
    feature_matrix[0,4] = np.sqrt(np.mean(temp**2))
    feature_matrix[0,5] = skewness(temp)
    feature_matrix[0,6] = kurtosis(temp)
    feature_matrix[0,7] = feature_matrix[0,0]/feature_matrix[0,4]
    feature_matrix[0,8] = feature_matrix[0,4]/feature_matrix[0,2]
    df1= pd.DataFrame(feature_matrix)
    df1.index = [filename[:-3]]
    set3bear3 = pd.concat([set3bear3,df1])

set3bear3.columns = ['Max', 'Min', 'Mean', 'Standard Deviation', 'RMS', 'Skewness', 'Kurtosis', 'Crest Factor', 'Form Factor']
set3bear3.index = pd.to_datetime(set3bear3.index, format ='%Y.%m.%d.%H.%M')
set3bear3.to_csv('Bearing_values_bearingno{}_testset{}.csv'.format(bearing_no,test_set))
set3bear3
# Out:
#                        Max    Min      Mean  Standard Deviation       RMS  \
# 2004-03-04 09:27:00  0.361 -0.310 -0.005148            0.066192  0.066390
# 2004-03-04 09:32:00  0.295 -0.295 -0.006310            0.065986  0.066285
# 2004-03-04 09:42:00  0.286 -0.286 -0.001293            0.069176  0.069186
# 2004-03-04 09:52:00  0.349 -0.310 -0.002280            0.068600  0.068637
# 2004-03-04 10:02:00  0.388 -0.374 -0.001727            0.067449  0.067469
# ...                    ...    ...       ...                 ...       ...
# 2004-04-18 02:02:00  3.167 -5.000  0.017613            0.495062  0.495363
# 2004-04-18 02:12:00  2.378 -3.899 -0.002114            0.454472  0.454466
# 2004-04-18 02:22:00  4.346 -5.000 -0.079840            0.584635  0.590047
# 2004-04-18 02:32:00  4.998 -5.000  0.052137            0.756990  0.758765
# 2004-04-18 02:42:00  0.007  0.000  0.003663            0.001520  0.003966
#
#                      Skewness   Kurtosis  Crest Factor  Form Factor
# 2004-03-04 09:27:00  0.083449   0.591902      5.437565   -12.896399
# 2004-03-04 09:32:00  0.011828   0.359751      4.450449   -10.505622
# 2004-03-04 09:42:00  0.049056   0.213724      4.133782   -53.519544
# 2004-03-04 09:52:00  0.002209   0.299035      5.084751   -30.099513
# 2004-03-04 10:02:00  0.031884   0.395754      5.750781   -39.058344
# ...                       ...        ...           ...          ...
# 2004-04-18 02:02:00 -1.648364  16.742241      6.393285    28.124430
# 2004-04-18 02:12:00 -0.656841   5.707273      5.232514  -214.967877
# 2004-04-18 02:22:00 -0.426006  12.660025      7.365514    -7.390347
# 2004-04-18 02:32:00 -0.220131   7.058920      6.587018    14.553238
# 2004-04-18 02:42:00 -0.135492  -1.826541      1.765154     1.082688
#
# [6324 rows x 9 columns]

# %%
#TEST SET 3 BEARING NO 4

set3bear4 = pd.DataFrame()
test_set = 3
bearing_no = 4
path = r'D:\Bearing project Dataset\3rd_test\4th_test\txt'
for filename in os.listdir(path):
    dataset = pd.read_csv(os.path.join(path,filename), sep = '\t', header = None)
    datarr = np.array(dataset.iloc[:,bearing_no-1])
    feature_matrix = np.zeros((1,9))
    temp = datarr
    feature_matrix[0,0] = np.max(temp)
    feature_matrix[0,1] = np.min(temp)
    feature_matrix[0,2] = np.mean(temp)
    feature_matrix[0,3] = np.std(temp, ddof =1)
    feature_matrix[0,4] = np.sqrt(np.mean(temp**2))
    feature_matrix[0,5] = skewness(temp)
    feature_matrix[0,6] = kurtosis(temp)
    feature_matrix[0,7] = feature_matrix[0,0]/feature_matrix[0,4]
    feature_matrix[0,8] = feature_matrix[0,4]/feature_matrix[0,2]
    df1= pd.DataFrame(feature_matrix)
    df1.index = [filename[:-3]]
    set3bear4 = pd.concat([set3bear4,df1])

set3bear4.columns = ['Max', 'Min', 'Mean', 'Standard Deviation', 'RMS', 'Skewness', 'Kurtosis', 'Crest Factor', 'Form Factor']
set3bear4.index = pd.to_datetime(set3bear4.index, format ='%Y.%m.%d.%H.%M')
set3bear4.to_csv('Bearing_values_bearingno{}_testset{}.csv'.format(bearing_no,test_set))
set3bear4
# Out:
#                        Max    Min      Mean  Standard Deviation       RMS  \
# 2004-03-04 09:27:00  0.254 -0.303 -0.004331            0.055325  0.055493
# 2004-03-04 09:32:00  0.212 -0.249 -0.006725            0.052926  0.053351
# 2004-03-04 09:42:00  0.278 -0.278 -0.003200            0.052607  0.052703
# 2004-03-04 09:52:00  0.269 -0.300 -0.004379            0.054671  0.054844
# 2004-03-04 10:02:00  0.227 -0.247 -0.003443            0.053805  0.053914
# ...                    ...    ...       ...                 ...       ...
# 2004-04-18 02:02:00  0.867 -0.955 -0.003682            0.248059  0.248081
# 2004-04-18 02:12:00  0.918 -0.813 -0.003608            0.253635  0.253654
# 2004-04-18 02:22:00  1.082 -1.104 -0.003425            0.279849  0.279863
# 2004-04-18 02:32:00  0.881 -0.969 -0.003452            0.282160  0.282174
# 2004-04-18 02:42:00  0.005 -0.002  0.001419            0.001187  0.001850
#
#                      Skewness  Kurtosis  Crest Factor  Form Factor
# 2004-03-04 09:27:00  0.038845  0.559706      4.577189   -12.813293
# 2004-03-04 09:32:00  0.013904  0.355708      3.973709    -7.932665
# 2004-03-04 09:42:00  0.034235  0.477955      5.274828   -16.469227
# 2004-03-04 09:52:00  0.007403  0.341732      4.904798   -12.524926
# 2004-03-04 10:02:00  0.023473  0.261460      4.210398   -15.660536
# ...                       ...       ...           ...          ...
# 2004-04-18 02:02:00 -0.026558  0.022271      3.494830   -67.379632
# 2004-04-18 02:12:00  0.104431 -0.257887      3.619096   -70.304147
# 2004-04-18 02:22:00  0.002889  0.030199      3.866172   -81.701455
# 2004-04-18 02:32:00 -0.108601 -0.486148      3.122183   -81.743400
# 2004-04-18 02:42:00  0.475456  1.016386      2.702101     1.303627
#
# [6324 rows x 9 columns]

# %%
df1 = pd.read_csv("Bearing_values_bearingno1_testset3.csv", index_col = 'Unnamed: 0')
df2 = pd.read_csv("Bearing_values_bearingno2_testset3.csv", index_col = 'Unnamed: 0')
df3 = pd.read_csv("Bearing_values_bearingno3_testset3.csv", index_col = 'Unnamed: 0')
df4 = pd.read_csv("Bearing_values_bearingno4_testset3.csv", index_col = 'Unnamed: 0')
df1.index = pd.to_datetime(df1.index)
for col in (df1.columns):
    plt.figure(figsize=(10,5))
    plt.plot(df1.index,df1[col])
    plt.plot(df1.index,df2[col])
    plt.plot(df1.index,df3[col])
    plt.plot(df1.index,df4[col])
    plt.legend(['bearing_1','bearing_2','bearing_3','bearing_4'])
    plt.xlabel('date and time')
    plt.ylabel(col)
    plt.title(col)
    plt.show()

# %%
df=df3['2004-04-15 12:32:00':'2004-04-18 00:42:00']
fault=[]
for i in range(0,len(df)):
    fault.append('Outer Race')
df['Fault']=fault
df
# Out:
# C:\Users\haris\AppData\Local\Temp\ipykernel_18300\2192930933.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fault']=fault
#                        Max    Min      Mean  Standard Deviation       RMS  \
# 2004-04-15 12:32:00  0.315 -0.300 -0.002260            0.071999  0.072032
# 2004-04-15 12:42:00  0.278 -0.320 -0.000929            0.071960  0.071965
# 2004-04-15 12:52:00  0.403 -0.300 -0.001721            0.071967  0.071986
# 2004-04-15 13:02:00  0.334 -0.332 -0.001242            0.070479  0.070488
# 2004-04-15 13:12:00  0.295 -0.334 -0.002482            0.072242  0.072283
# ...                    ...    ...       ...                 ...       ...
# 2004-04-18 00:02:00  2.280 -3.936 -0.001821            0.394083  0.394077
# 2004-04-18 00:12:00  1.750 -3.423 -0.002377            0.395931  0.395928
# 2004-04-18 00:22:00  2.202 -3.013 -0.004019            0.384375  0.384387
# 2004-04-18 00:32:00  1.824 -3.335 -0.003547            0.373875  0.373883
# 2004-04-18 00:42:00  2.842 -4.939 -0.002901            0.502699  0.502695
#
#                      Skewness  Kurtosis  Crest Factor  Form Factor       Fault
# 2004-04-15 12:32:00 -0.017350  0.161074      4.373034   -31.867085  Outer Race
# 2004-04-15 12:42:00 -0.020822  0.203632      3.863014   -77.468263  Outer Race
# 2004-04-15 12:52:00  0.009853  0.275335      5.598312   -41.838775  Outer Race
# 2004-04-15 13:02:00  0.037436  0.131765      4.738400   -56.769549  Outer Race
# 2004-04-15 13:12:00 -0.030286  0.181303      4.081162   -29.120361  Outer Race
# ...                       ...       ...           ...          ...         ...
# 2004-04-18 00:02:00 -0.416217  6.095530      5.785668  -216.407494  Outer Race
# 2004-04-18 00:12:00 -0.664070  3.988261      4.419990  -166.549208  Outer Race
# 2004-04-18 00:22:00 -0.150122  2.377175      5.728602   -95.651873  Outer Race
# 2004-04-18 00:32:00 -0.408740  4.726666      4.878529  -105.403295  Outer Race
# 2004-04-18 00:42:00 -0.363187  6.183888      5.653532  -173.296282  Outer Race
#
# [362 rows x 10 columns]

# %%
df.to_csv('Outer_Race_Fault_set3.csv',index=False)
